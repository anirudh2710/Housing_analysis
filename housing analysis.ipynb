# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('realtor-data.csv')

# %% [markdown]
# #### Raw data

# %%
df.head()
# Out:
#      status  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 4  for_sale  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 1      1527.0            NaN   80000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0
# 4         NaN            NaN   65000.0

# %%
df.shape #unclean data size
# Out:
# (904966, 10)

# %%
df.isnull().sum()
# Out:
# status                 0
# bed               129840
# bath              113884
# acre_lot          266642
# city                  72
# state                  0
# zip_code             204
# house_size        292886
# prev_sold_date    459101
# price                 71
# dtype: int64

# %% [markdown]
# ### Data preprocessing

# %%
df1 = df.copy()

# %%
df1 = df1.drop(['prev_sold_date'],axis=1) #dropping unwanted columns - prev_sold_date

# %%
df1.isnull().sum()
# Out:
# status             0
# bed           129840
# bath          113884
# acre_lot      266642
# city              72
# state              0
# zip_code         204
# house_size    292886
# price             71
# dtype: int64

# %%
df1['bed'].fillna(np.random.randint(1,4),inplace=True) #replacing NaN values with random(1-4) beds

# %%
df1 = df1.loc[df1['bed']<=4]

# %%
df1['bed'].unique()
# Out:
# array([3., 4., 2., 1.])

# %%
df1['bath'].fillna(np.random.randint(1,3),inplace = True)

# %%
df1.isnull().sum()
# Out:
# status             0
# bed                0
# bath               0
# acre_lot      255689
# city              62
# state              0
# zip_code         201
# house_size    257654
# price             62
# dtype: int64

# %%
df1.head()
# Out:
#      status  bed  bath  acre_lot           city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 1  for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 5  for_sale  4.0   3.0      0.46  San Sebastian  Puerto Rico     612.0
#
#    house_size     price
# 0       920.0  105000.0
# 1      1527.0   80000.0
# 2       748.0   67000.0
# 3      1800.0  145000.0
# 5      2520.0  179000.0

# %%
df2 = df1.copy()

# %%
df2 = df2.drop(df2[df2['price'].isnull()].index) #dropping Nan values in price

# %%
df2 = df2.drop(df2[df2['city'].isnull()].index) #dropping Nan values in city

# %%
df2 = df2.drop(df2[df2['zip_code'].isnull()].index) #dropping Nan values in zipcode

# %%
df2.isnull().sum()
# Out:
# status             0
# bed                0
# bath               0
# acre_lot      255591
# city               0
# state              0
# zip_code           0
# house_size    257564
# price              0
# dtype: int64

# %%
df2
# Out:
#           status  bed  bath  acre_lot           city        state  zip_code  \
# 0       for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 1       for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 2       for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3       for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 5       for_sale  4.0   3.0      0.46  San Sebastian  Puerto Rico     612.0
# ...          ...  ...   ...       ...            ...          ...       ...
# 904961  for_sale  2.0   2.0       NaN  New York City     New York   10463.0
# 904962  for_sale  2.0   2.0       NaN          Bronx     New York   10463.0
# 904963  for_sale  1.0   1.0       NaN          Bronx     New York   10463.0
# 904964  for_sale  3.0   2.0       NaN          Bronx     New York   10463.0
# 904965  for_sale  3.0   3.0       NaN  New York City     New York   10463.0
#
#         house_size     price
# 0            920.0  105000.0
# 1           1527.0   80000.0
# 2            748.0   67000.0
# 3           1800.0  145000.0
# 5           2520.0  179000.0
# ...            ...       ...
# 904961         NaN  359000.0
# 904962      1200.0  299000.0
# 904963         NaN  120000.0
# 904964         NaN  449000.0
# 904965      1677.0  850000.0
#
# [774584 rows x 9 columns]

# %%
housing_data=df2 #imputing nan values of house_size with linear regression predicted values

# %% [markdown]
# #### Building a Linear regression model on missing 'house_size' values based on number of beds, number of baths, city, state since it can't be randomly populated or deleted.

# %%
housing_data["city_num"] = housing_data["city"].astype("category").cat.codes
housing_data["state_num"] = housing_data["state"].astype("category").cat.codes

features = ["bed", "bath", "city_num", "state_num","price"]

housing_data_no_nan = housing_data[~np.isnan(housing_data["house_size"])]

model = LinearRegression()
model.fit(housing_data_no_nan[features], housing_data_no_nan["house_size"])

house_size_imputed = housing_data["house_size"].copy()
house_size_imputed[np.isnan(house_size_imputed)] = model.predict(housing_data[features][np.isnan(house_size_imputed)])

housing_data["house_size"] = house_size_imputed

# %%
housing_data.isnull().sum()
# Out:
# status             0
# bed                0
# bath               0
# acre_lot      255591
# city               0
# state              0
# zip_code           0
# house_size         0
# price              0
# city_num           0
# state_num          0
# dtype: int64

# %%
housing_data.head(60)
# Out:
#       status  bed  bath  acre_lot           city        state  zip_code  \
# 0   for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 1   for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 2   for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3   for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 5   for_sale  4.0   3.0      0.46  San Sebastian  Puerto Rico     612.0
# 6   for_sale  3.0   1.0      0.20         Ciales  Puerto Rico     639.0
# 7   for_sale  3.0   2.0      0.08          Ponce  Puerto Rico     731.0
# 8   for_sale  2.0   1.0      0.09          Ponce  Puerto Rico     730.0
# 10  for_sale  3.0   2.0     13.39        Isabela  Puerto Rico     662.0
# 11  for_sale  3.0   2.0      0.08     Juana Diaz  Puerto Rico     795.0
# 12  for_sale  3.0   2.0      0.10          Lares  Puerto Rico     669.0
# 15  for_sale  3.0   2.0      0.08          Yauco  Puerto Rico     698.0
# 16  for_sale  4.0   4.0      0.22       Mayaguez  Puerto Rico     680.0
# 17  for_sale  3.0   2.0      0.08          Ponce  Puerto Rico     728.0
# 18  for_sale  3.0   2.0      3.88  San Sebastian  Puerto Rico     685.0
# 20  for_sale  2.0   1.0      0.23          Yauco  Puerto Rico     698.0
# 22  for_sale  3.0   1.0      2.00          Coamo  Puerto Rico     769.0
# 23  for_sale  3.0   2.0       NaN          Ponce  Puerto Rico     716.0
# 24  for_sale  3.0   2.0      0.05          Yauco  Puerto Rico     698.0
# 25  for_sale  3.0   2.0      0.28  San Sebastian  Puerto Rico     685.0
# 26  for_sale  4.0   3.0      0.30          Ponce  Puerto Rico     730.0
# 27  for_sale  4.0   2.0      0.11     Guayanilla  Puerto Rico     656.0
# 28  for_sale  4.0   2.0      0.04         Manati  Puerto Rico     676.0
# 29  for_sale  3.0   2.0      0.69        Isabela  Puerto Rico     662.0
# 32  for_sale  4.0   2.0      3.08   Santa Isabel  Puerto Rico     757.0
# 33  for_sale  1.0   1.0      0.10          Ponce  Puerto Rico     730.0
# 34  for_sale  3.0   1.0      0.23          Yauco  Puerto Rico     698.0
# 35  for_sale  3.0   2.0      1.13           Moca  Puerto Rico     676.0
# 36  for_sale  4.0   4.0      4.84  San Sebastian  Puerto Rico     685.0
# 37  for_sale  3.0   4.0      1.94         Utuado  Puerto Rico     641.0
# 38  for_sale  4.0   2.0      0.24     Las Marias  Puerto Rico     670.0
# 42  for_sale  1.0   2.0      0.99           Moca  Puerto Rico     676.0
# 43  for_sale  1.0   2.0     18.45        Hatillo  Puerto Rico     659.0
# 44  for_sale  3.0   2.0      0.10         Aguada  Puerto Rico     602.0
# 45  for_sale  3.0   1.0      0.09         Aguada  Puerto Rico     602.0
# 46  for_sale  4.0   2.0      0.15         Aguada  Puerto Rico     602.0
# 47  for_sale  1.0   1.0      0.26         Aguada  Puerto Rico     602.0
# 48  for_sale  2.0   2.0      0.24         Aguada  Puerto Rico     602.0
# 49  for_sale  3.0   2.0      0.13         Aguada  Puerto Rico     602.0
# 51  for_sale  2.0   1.0       NaN         Aguada  Puerto Rico     602.0
# 52  for_sale  2.0   1.0      0.07         Aguada  Puerto Rico     602.0
# 54  for_sale  4.0   2.0      0.10         Aguada  Puerto Rico     602.0
# 55  for_sale  3.0   2.0      0.08         Aguada  Puerto Rico     602.0
# 57  for_sale  3.0   4.0      2.00         Aguada  Puerto Rico     602.0
# 58  for_sale  3.0   2.0      2.96         Aguada  Puerto Rico     602.0
# 59  for_sale  1.0   2.0      0.88         Aguada  Puerto Rico     602.0
# 60  for_sale  1.0   2.0      0.21         Aguada  Puerto Rico     602.0
# 61  for_sale  1.0   2.0     21.08         Aguada  Puerto Rico     602.0
# 68   1228.431236   249500.0        16          9
# 71   1281.643244   649000.0        16          9
# 72    951.000000   189000.0        16          9
# 73   1215.178183   150000.0        16          9
# 74   1205.055247    74000.0        16          9
# 75   1203.923077    65500.0        16          9
# 76   1204.189470    67500.0        16          9

# %%
df3 = housing_data

# %%
df3["acre_lot"] = df3["acre_lot"].fillna(df3["acre_lot"].median()) #population NaN acre_lot values with median of the column

# %%
df3.isnull().sum()
# Out:
# status        0
# bed           0
# bath          0
# acre_lot      0
# city          0
# state         0
# zip_code      0
# house_size    0
# price         0
# city_num      0
# state_num     0
# dtype: int64

# %%
df3.dtypes
# Out:
# status         object
# bed           float64
# bath          float64
# acre_lot      float64
# city           object
# state          object
# zip_code      float64
# house_size    float64
# price         float64
# city_num        int16
# state_num        int8
# dtype: object

# %%
df3['bed'] = df3['bed'].astype('int64') # changing the data type of bed,bath,price,zip_code, house_size from float to int
df3['bath'] = df3['bath'].astype('int64')
df3['price'] = df3['price'].astype('int64')
df3['zip_code'] = df3['zip_code'].astype('int64')
df3['house_size'] = df3['house_size'].astype('int64')

# %%
df3 = df3.drop(['city_num','state_num','status'],axis=1) #removing unwanted columns

# %%
df3
# Out:
#         bed  bath  acre_lot           city        state  zip_code  house_size  \
# 0         3     2      0.12       Adjuntas  Puerto Rico       601         920
# 1         4     2      0.08       Adjuntas  Puerto Rico       601        1527
# 2         2     1      0.15     Juana Diaz  Puerto Rico       795         748
# 3         4     2      0.10          Ponce  Puerto Rico       731        1800
# 5         4     3      0.46  San Sebastian  Puerto Rico       612        2520
# ...     ...   ...       ...            ...          ...       ...         ...
# 904961    2     2      0.33  New York City     New York     10463        1461
# 904962    2     2      0.33          Bronx     New York     10463        1200
# 904963    1     1      0.33          Bronx     New York     10463         673
# 904964    3     2      0.33          Bronx     New York     10463        1672
# 904965    3     3      0.33  New York City     New York     10463        1677
#
#          price
# 0       105000
# 1        80000
# 2        67000
# 3       145000
# 5       179000
# ...        ...
# 904961  359000
# 904962  299000
# 904963  120000
# 904964  449000
# 904965  850000
#
# [774584 rows x 8 columns]

# %%
housing_data.head(60)
# Out:
#       status  bed  bath  acre_lot           city        state  zip_code  \
# 0   for_sale    3     2      0.12       Adjuntas  Puerto Rico       601
# 1   for_sale    4     2      0.08       Adjuntas  Puerto Rico       601
# 2   for_sale    2     1      0.15     Juana Diaz  Puerto Rico       795
# 3   for_sale    4     2      0.10          Ponce  Puerto Rico       731
# 5   for_sale    4     3      0.46  San Sebastian  Puerto Rico       612
# 6   for_sale    3     1      0.20         Ciales  Puerto Rico       639
# 7   for_sale    3     2      0.08          Ponce  Puerto Rico       731
# 8   for_sale    2     1      0.09          Ponce  Puerto Rico       730
# 10  for_sale    3     2     13.39        Isabela  Puerto Rico       662
# 11  for_sale    3     2      0.08     Juana Diaz  Puerto Rico       795
# 12  for_sale    3     2      0.10          Lares  Puerto Rico       669
# 74  for_sale    1     2      0.21         Aguada  Puerto Rico       602
# 75  for_sale    1     2      0.28         Aguada  Puerto Rico       602
# 76  for_sale    1     2      0.28         Aguada  Puerto Rico       602
#
#     house_size    price  city_num  state_num
# 0          920   105000        14          9
# 1         1527    80000        14          9
# 2          748    67000      1042          9
# 3         1800   145000      1705          9
# 5         2520   179000      1879          9
# 6         2040    50000       407          9
# 7         1050    71600      1705          9
# 8         1092   100000      1705          9
# 10        1106    89000      1011          9
# 11        1045   150000      1042          9
# 12        4161   155000      1109          9
# 15        1100   120000      2451          9
# 16        3450   235000      1273          9
# 17        1500   105000      1705          9
# 18        4000   575000      1879          9
# 20         621    50000      2451          9
# 22        1213   189000       432          9
# 23        1148   115000      1705          9
# 24        1118   122500      2451          9
# 25        1500   255000      1879          9
# 26        3000   425000      1705          9
# 27        1300    93000       863          9
# 28        1080    75000      1227          9
# 29        2505   469000      1011          9
# 32        2886   495000      1891          9
# 33         850   220000      1705          9
# 34         936    70500      2451          9
# 35        1928   305000      1343          9
# 36        3690   475000      1879          9
# 37        2500   195000      2196          9
# 38        1800   120000      1110          9
# 42       43082   400000      1343          9
# 43        1252   380000       922          9
# 44         600    95000        16          9
# 45         900    74000        16          9
# 46        3000   139500        16          9
# 47        2100   149900        16          9
# 48        1138   180000        16          9
# 49        1380   249000        16          9
# 51         813   160000        16          9
# 52         813    90000        16          9
# 54        1955   339000        16          9
# 55        1200   265000        16          9
# 57        1880   389000        16          9
# 58        2500   575000        16          9
# 59        1199    35000        16          9
# 60        1202    58000        16          9
# 61        1206    85000        16          9
# 62        1201    47000        16          9
# 63        2715   720000        16          9
# 65        1201    50000        16          9
# 66        3798  3250000      1790          9
# 67        1200    39500        16          9
# 68        1228   249500        16          9
# 71        1281   649000        16          9
# 72         951   189000        16          9
# 73        1215   150000        16          9
# 74        1205    74000        16          9
# 75        1203    65500        16          9
# 76        1204    67500        16          9

# %%
df3['bath'].unique()
# Out:
# array([ 2,  1,  3,  4,  6,  7,  5, 10,  8,  9, 20, 29, 18, 13, 15, 11, 16,
#        12, 22])

# %%
df3.isnull().sum()
# Out:
# bed           0
# bath          0
# acre_lot      0
# city          0
# state         0
# zip_code      0
# house_size    0
# price         0
# dtype: int64

# %%
df3 = df3.loc[df3['bath']<=4] #removing erraneous bath values

# %%
df3
# Out:
#         bed  bath  acre_lot           city        state  zip_code  house_size  \
# 0         3     2      0.12       Adjuntas  Puerto Rico       601         920
# 1         4     2      0.08       Adjuntas  Puerto Rico       601        1527
# 2         2     1      0.15     Juana Diaz  Puerto Rico       795         748
# 3         4     2      0.10          Ponce  Puerto Rico       731        1800
# 5         4     3      0.46  San Sebastian  Puerto Rico       612        2520
# ...     ...   ...       ...            ...          ...       ...         ...
# 904961    2     2      0.33  New York City     New York     10463        1461
# 904962    2     2      0.33          Bronx     New York     10463        1200
# 904963    1     1      0.33          Bronx     New York     10463         673
# 904964    3     2      0.33          Bronx     New York     10463        1672
# 904965    3     3      0.33  New York City     New York     10463        1677
#
#          price
# 0       105000
# 1        80000
# 2        67000
# 3       145000
# 5       179000
# ...        ...
# 904961  359000
# 904962  299000
# 904963  120000
# 904964  449000
# 904965  850000
#
# [761595 rows x 8 columns]

# %% [markdown]
# #### Download clean data

# %%
df3.to_csv('housing_data.csv')

# %% [markdown]
# #### Finding average house price per zipcode

# %%
df4 = df3.copy()

# %%
df4.head()
# Out:
#    bed  bath  acre_lot           city        state  zip_code  house_size  \
# 0    3     2      0.12       Adjuntas  Puerto Rico       601         920
# 1    4     2      0.08       Adjuntas  Puerto Rico       601        1527
# 2    2     1      0.15     Juana Diaz  Puerto Rico       795         748
# 3    4     2      0.10          Ponce  Puerto Rico       731        1800
# 5    4     3      0.46  San Sebastian  Puerto Rico       612        2520
#
#     price
# 0  105000
# 1   80000
# 2   67000
# 3  145000
# 5  179000

# %%
df4=df4.drop(['bed','bath','acre_lot','city','state','house_size'],axis=1)

# %%
df4.head()
# Out:
#    zip_code   price
# 0       601  105000
# 1       601   80000
# 2       795   67000
# 3       731  145000
# 5       612  179000

# %%
df4 = df4.groupby('zip_code').mean() #Averaging the house price for each zipcode

# %%
df4.reset_index(inplace=True)

# %%
df4.head()
# Out:
#    zip_code          price
# 0       601   92878.787879
# 1       602  190157.733990
# 2       603  301950.596685
# 3       604   79900.000000
# 4       605  171200.000000

# %%
df4.dtypes
# Out:
# zip_code      int64
# price       float64
# dtype: object

# %%
df4['price'] = df4['price'].astype('int64')

# %% [markdown]
# #### Average house price per Zipcode

# %%
df4.head()
# Out:
#    zip_code   price
# 0       601   92878
# 1       602  190157
# 2       603  301950
# 3       604   79900
# 4       605  171200

# %%
def check_condition(row):
    zip_code = row['zip_code']
    price = row['price']
    
    current_index = df4.index[df4['zip_code'] == zip_code][0] # Find the indices of the neighboring rows
    prev_index = current_index - 1
    next_index = current_index + 1
    
    if prev_index >= 0 and next_index < len(df4):             # Check if the current price meets the condition
        prev_price = df4.loc[prev_index, 'price']
        next_price = df4.loc[next_index, 'price']
        return 3 * price < prev_price and 3 * price < next_price
    else:
        return False

result = df4[df4.apply(check_condition, axis=1)]

selected_zip_codes = result['zip_code'].tolist()              # Get the zip codes that meet the condition
print("Zipcodes with high disparities in average house prices that are lower than the neighbouring zipcodes-->",selected_zip_codes)
# Out:
# Zipcodes with high disparities in average house prices that are lower than the neighbouring zipcodes--> [656, 661, 719, 777, 910, 970, 1011, 1235, 1243, 2553, 2571, 2714, 3240, 3260, 3273, 3785, 3864, 4020, 4022, 4056, 4237, 4280, 4343, 4419, 4479, 4492, 4539, 4544, 4553, 4680, 4763, 4777, 4923, 5070, 5252, 5494, 5650, 5675, 5746, 5827, 5831, 5858, 5862, 6336, 6350, 6373, 7710, 8007, 8073, 8252, 10924, 11431, 11953, 11961, 12033, 12165, 12565, 12746, 12864, 12988, 18040, 18342, 19374, 29835, 37760]
